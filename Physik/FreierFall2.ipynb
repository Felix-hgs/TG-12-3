# %%
import numpy as np
import matplotlib.pyplot as plt

tend = 10
dt = 0.1
t = 0
v = 0
s = 0
g = 9.81
h0 = 0
p = int(tend//dt)

strecke=[]
zeit=[]
geschwindigkeit=[]
streckea=[]

for i in range (1,p):
    t += dt
    a = g
    v = v + a * dt
    s = s + v * dt
    ht = h0 + 0.5 * a * t**2
    vt = g * t
    print (f"t={t:5.2f} s, v={v:8.3f} m/s, s={s:8.3f} m",f" ht={ht:8.3f} m",f" vt={vt:8.3f} m/s")
    streckea.append(ht)
    strecke.append(s)
    zeit.append(t)
    geschwindigkeit.append(v)
    





fig=plt.figure()
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)
ax1.set_ylabel('geschwindigkeit in m/s')
ax1.set_xlabel('zeit in s')
ax1.grid(True)
ax2.set_xlabel('zeit in s')
ax2.set_ylabel('strecke in m')
ax2.grid(True)
ax1.plot(zeit,geschwindigkeit,label='f(x)',color='red')
ax2.plot(zeit,strecke,label='g(x)',color='blue')
ax2.plot(zeit,streckea,label='g(x)',color='green')
ax1.legend()
ax2.legend()
plt.show()
# Out:
# t= 0.10 s, v=   0.981 m/s, s=   0.098 m  ht=   0.049 m  vt=   0.981 m/s
# t= 0.20 s, v=   1.962 m/s, s=   0.294 m  ht=   0.196 m  vt=   1.962 m/s
# t= 0.30 s, v=   2.943 m/s, s=   0.589 m  ht=   0.441 m  vt=   2.943 m/s
# t= 0.40 s, v=   3.924 m/s, s=   0.981 m  ht=   0.785 m  vt=   3.924 m/s
# t= 0.50 s, v=   4.905 m/s, s=   1.472 m  ht=   1.226 m  vt=   4.905 m/s
# t= 0.60 s, v=   5.886 m/s, s=   2.060 m  ht=   1.766 m  vt=   5.886 m/s
# t= 0.70 s, v=   6.867 m/s, s=   2.747 m  ht=   2.403 m  vt=   6.867 m/s
# t= 0.80 s, v=   7.848 m/s, s=   3.532 m  ht=   3.139 m  vt=   7.848 m/s
# t= 0.90 s, v=   8.829 m/s, s=   4.415 m  ht=   3.973 m  vt=   8.829 m/s
# t= 1.00 s, v=   9.810 m/s, s=   5.396 m  ht=   4.905 m  vt=   9.810 m/s
# t= 1.10 s, v=  10.791 m/s, s=   6.475 m  ht=   5.935 m  vt=  10.791 m/s
# t= 1.20 s, v=  11.772 m/s, s=   7.652 m  ht=   7.063 m  vt=  11.772 m/s
# t= 1.30 s, v=  12.753 m/s, s=   8.927 m  ht=   8.289 m  vt=  12.753 m/s
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

tend = 60
dt = 0.1
dt2 = dt
t = 0
v = 0
s = 100  # Start aus 4000 m Höhe
s2 = s
t2 = t
v2 = 2
Startwert = s
g = 9.81
cw = 1.1
A = 72.505  # typische Fläche in m²
A2 = 0.7  # Fläche in m² für geschlossenen Fallschirm (nur Körper)
pl = 1.23
m = 80  # Masse in kg
p = int(tend // dt)

strecke = [s]
zeit = [t]
geschwindigkeit = [v]
strecke2 = [s2]
geschwindigkeit2 = [v2]
zeit2 = [t2]
for i in range(1, p):
    Fw = 0.5 * cw * A * pl * v * abs(v)  # Luftwiderstand, immer entgegen der Richtung
    FW2 = 0.5 * cw * A2 *pl * v * abs(v)
    a = g - Fw / m
    a2 = g - Fw / m
    v = v + a * dt
    v2 = v2 + a2 * dt2
    s = s - v * dt  # Höhe nimmt ab beim Fallen
    s2 = s2 -v2 * dt2
    t = t + dt
    t2 = t2 + dt2
    print(f"t={t:5.2f} s, v={v:8.6f} m/s, s={s:8.3f} m")
    if s <= 0:
        s = 0
        strecke.append(s)
        zeit.append(t)
        geschwindigkeit.append(v)
        break
    if s2 <= 0:
        s = 0
        strecke2.append(s2)
        zeit2.append(t2)
        geschwindigkeit2.append(v2)
        break
    strecke.append(s)
    zeit.append(t)
    geschwindigkeit.append(v)
    strecke2.append(s2)
    geschwindigkeit2.append(v2)
    zeit2.append(t2)


fig=plt.figure(figsize=(10, 5))
ax1=fig.add_subplot(2, 1, 1)
ax1.plot(zeit,geschwindigkeit,label='f(x) Fallschirm offen mit luftwiederstand',color='red')
ax1.plot(zeit,np.array(zeit)*g,label='g(x) ohne luftwiederstand',color='green')
ax1.plot(zeit2,geschwindigkeit2,label='k(x) Fallschirm zu mit luftwiederstand',color='blue')
ax1.set_ylabel('Geschwindigkeit (m/s)')
ax1.set_xlabel('zeit in s')
ax1.grid(True)
plt.legend()
print("Driftgeschwindigkeit = ", np.sqrt(2 * m * g / (cw * A * pl)), "m/s")
ax2=fig.add_subplot(2,1,2)
ax2.plot(zeit,strecke,label='f(x) Fallschirm offen mit luftwiederstand',color='red')
ax2.plot(zeit2,strecke2,label='k(x) Fallschirm zu mit luftwiederstand',color='blue')
ax2.plot(zeit,Startwert-0.5*g*np.array(zeit)**2,label='g(x) ohne luftwiederstand',color='green')
ax2.set_xlabel('zeit in s')
ax2.set_ylabel('strecke in m')
ax2.grid(True)
ax2.set_ylim(bottom=0)
ax1.legend()
ax2.legend()
plt.show()
# Out:
# t= 0.10 s, v=0.981000 m/s, s=  99.902 m
# t= 0.20 s, v=1.902996 m/s, s=  99.712 m
# t= 0.30 s, v=2.661961 m/s, s=  99.445 m
# t= 0.40 s, v=3.208501 m/s, s=  99.125 m
# t= 0.50 s, v=3.558326 m/s, s=  98.769 m
# t= 0.60 s, v=3.763012 m/s, s=  98.392 m
# t= 0.70 s, v=3.875818 m/s, s=  98.005 m
# t= 0.80 s, v=3.935791 m/s, s=  97.611 m
# t= 0.90 s, v=3.967040 m/s, s=  97.215 m
# t= 1.00 s, v=3.983147 m/s, s=  96.816 m
# t= 1.10 s, v=3.991403 m/s, s=  96.417 m
# t= 1.20 s, v=3.995623 m/s, s=  96.018 m
# t= 1.30 s, v=3.997776 m/s, s=  95.618 m
# t= 1.40 s, v=3.998874 m/s, s=  95.218 m
# t= 1.50 s, v=3.999434 m/s, s=  94.818 m
# t= 1.60 s, v=3.999719 m/s, s=  94.418 m
# t= 1.70 s, v=3.999864 m/s, s=  94.018 m
# t= 1.80 s, v=3.999938 m/s, s=  93.618 m
# t= 1.90 s, v=3.999976 m/s, s=  93.218 m
# t= 2.00 s, v=3.999995 m/s, s=  92.818 m
# t= 2.10 s, v=4.000005 m/s, s=  92.418 m
# t= 2.20 s, v=4.000010 m/s, s=  92.018 m
# t= 2.30 s, v=4.000012 m/s, s=  91.618 m
# ...
